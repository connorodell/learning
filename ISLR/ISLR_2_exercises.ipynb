# %% [markdown]
# ## Exercise 8
#
# Use college data set locative in file calles College.csv. The dataset can be found on the ISLR book website.

# %% [markdown]
# (a) Load the data into R as college

# %%
college = read.csv('College.csv')

# %% [markdown]
# (b) Look at the data using fix(). Note: The fix function doesn't work well in the jupyter notebook. It seems better just to type the data.frame name and enter.

# %%
college
# Out:
#     X                                       Private Apps  Accept Enroll
# 1   Abilene Christian University            Yes      1660  1232   721
# 2   Adelphi University                      Yes      2186  1924   512
# 3   Adrian College                          Yes      1428  1097   336
# 4   Agnes Scott College                     Yes       417   349   137
# 5   Alaska Pacific University               Yes       193   146    55
# 6   Albertson College                       Yes       587   479   158
# 7   Albertus Magnus College                 Yes       353   340   103
# 8   Albion College                          Yes      1899  1720   489
# 9   Albright College                        Yes      1038   839   227
# 10  Alderson-Broaddus College               Yes       582   498   172
# 11  Alfred University                       Yes      1732  1425   472
# 12  Allegheny College                       Yes      2652  1900   484
# ...

# %%
# Rename the rows using the university name in first column
rownames(college) = college[,1]
college
# Out:
#                                         X
# Abilene Christian University            Abilene Christian University
# Adelphi University                      Adelphi University
# Adrian College                          Adrian College
# Agnes Scott College                     Agnes Scott College
# Alaska Pacific University               Alaska Pacific University
# Albertson College                       Albertson College
# Albertus Magnus College                 Albertus Magnus College
# Albion College                          Albion College
# Albright College                        Albright College
# Alderson-Broaddus College               Alderson-Broaddus College
# Alfred University                       Alfred University
# Allegheny College                       Allegheny College
# Allentown Coll. of St. Francis de Sales Allentown Coll. of St. Francis de Sales
# Alma College                            Alma College
# Alverno College                         Alverno College
# ...

# %%
# Drop the first column
college = college[,-1]
college
# Out:
#                                         Private Apps  Accept Enroll Top10perc
# Abilene Christian University            Yes      1660  1232   721   23
# Adelphi University                      Yes      2186  1924   512   16
# Adrian College                          Yes      1428  1097   336   22
# Agnes Scott College                     Yes       417   349   137   60
# Alaska Pacific University               Yes       193   146    55   16
# Albertson College                       Yes       587   479   158   38
# Albertus Magnus College                 Yes       353   340   103   17
# Albion College                          Yes      1899  1720   489   37
# Albright College                        Yes      1038   839   227   30
# Alderson-Broaddus College               Yes       582   498   172   21
# Alfred University                       Yes      1732  1425   472   37
# Allegheny College                       Yes      2652  1900   484   44
# ...

# %% [markdown]
# (c)

# %%
# view summary of data
summary(college)
# Out:
#  Private        Apps           Accept          Enroll       Top10perc
#  No :212   Min.   :   81   Min.   :   72   Min.   :  35   Min.   : 1.00
#  Yes:565   1st Qu.:  776   1st Qu.:  604   1st Qu.: 242   1st Qu.:15.00
#            Median : 1558   Median : 1110   Median : 434   Median :23.00
#            Mean   : 3002   Mean   : 2019   Mean   : 780   Mean   :27.56
#            3rd Qu.: 3624   3rd Qu.: 2424   3rd Qu.: 902   3rd Qu.:35.00
#            Max.   :48094   Max.   :26330   Max.   :6392   Max.   :96.00
#    Top25perc      F.Undergrad     P.Undergrad         Outstate
#  Min.   :  9.0   Min.   :  139   Min.   :    1.0   Min.   : 2340
#  1st Qu.: 41.0   1st Qu.:  992   1st Qu.:   95.0   1st Qu.: 7320
#  Median : 54.0   Median : 1707   Median :  353.0   Median : 9990
#  Mean   : 55.8   Mean   : 3700   Mean   :  855.3   Mean   :10441
#  3rd Qu.: 69.0   3rd Qu.: 4005   3rd Qu.:  967.0   3rd Qu.:12925
#  Max.   :100.0   Max.   :31643   Max.   :21836.0   Max.   :21700
# ...

# %%
# use pairs() to create scatterplot matrix for first ten columns
pairs(college[,1:10])
# Out:
# plot without title

# %%
# Boxplots for Outstate and Private
attach(college) # make column names accessible
Private = as.factor(Private) # make Private into qualitative variables
plot(Private, Outstate)
# Out:
# plot without title

# %%
# create new binned variable Elite
Elite = rep('No', nrow(college))
Elite[college$Top10perc>50] = 'Yes'
Elite = as.factor(Elite)
college = data.frame(college, Elite)

# %%
summary(college) # there are 78 elite universities in the data set
# Out:
#  Private        Apps           Accept          Enroll       Top10perc
#  No :212   Min.   :   81   Min.   :   72   Min.   :  35   Min.   : 1.00
#  Yes:565   1st Qu.:  776   1st Qu.:  604   1st Qu.: 242   1st Qu.:15.00
#            Median : 1558   Median : 1110   Median : 434   Median :23.00
#            Mean   : 3002   Mean   : 2019   Mean   : 780   Mean   :27.56
#            3rd Qu.: 3624   3rd Qu.: 2424   3rd Qu.: 902   3rd Qu.:35.00
#            Max.   :48094   Max.   :26330   Max.   :6392   Max.   :96.00
#    Top25perc      F.Undergrad     P.Undergrad         Outstate
#  Min.   :  9.0   Min.   :  139   Min.   :    1.0   Min.   : 2340
#  1st Qu.: 41.0   1st Qu.:  992   1st Qu.:   95.0   1st Qu.: 7320
#  Median : 54.0   Median : 1707   Median :  353.0   Median : 9990
#  Mean   : 55.8   Mean   : 3700   Mean   :  855.3   Mean   :10441
#  3rd Qu.: 69.0   3rd Qu.: 4005   3rd Qu.:  967.0   3rd Qu.:12925
#  Max.   :100.0   Max.   :31643   Max.   :21836.0   Max.   :21700
# ...

# %%
# boxplot of Outstate vs Elite
plot(Elite, Outstate)
# Out:
# plot without title

# %%
# Create some histograms for quantitative variables
par(mfrow=c(3,2))
hist(Outstate)
hist(Outstate, breaks=30)
hist(Apps)
hist(Apps, breaks=20)
hist(PhD)
hist(PhD, breaks=5)
# Out:
# Plot with title “Histogram of PhD”

# %%
# more data exploration
plot(Elite, Books) # elite universities don't appear to use more expensive books
# Out:
# plot without title

# %%
plot(Elite, Expend) # Elite colleges do tend to cost more overall
# Out:
# plot without title

# %%
plot(Elite, PhD) # Elite colleges have more faculty members with PhDs
# Out:
# plot without title

# %%
plot(Expend, PhD) # cost has a nonlinear relationship with the number of PhD faculty
# Out:
# plot without title

# %%
plot(Private, Elite, xlab='Private', ylab='Elite') # Elite schools comprise a larger part of private schools
# Out:
# Plot with title “”

# %% [markdown]
# ## Exercise 9
#
# Questions about the Auto data set.

# %%
Auto = read.csv('Auto.csv', header=T, na.strings='?')
Auto = na.omit(Auto)
attach(Auto)
# Out:
# The following objects are masked from Auto (pos = 3):
#
#     acceleration, cylinders, displacement, horsepower, mpg, name,
#     origin, weight, year
#
# The following objects are masked from Auto (pos = 4):
#
#     acceleration, cylinders, displacement, horsepower, mpg, name,
#     origin, weight, year
#
# The following objects are masked from Auto (pos = 5):
#
#     acceleration, cylinders, displacement, horsepower, mpg, name,
#     origin, weight, year

# %%
summary(Auto)
# Out:
#       mpg          cylinders      displacement     horsepower        weight
#  Min.   : 9.00   Min.   :3.000   Min.   : 68.0   Min.   : 46.0   Min.   :1613
#  1st Qu.:17.00   1st Qu.:4.000   1st Qu.:105.0   1st Qu.: 75.0   1st Qu.:2225
#  Median :22.75   Median :4.000   Median :151.0   Median : 93.5   Median :2804
#  Mean   :23.45   Mean   :5.472   Mean   :194.4   Mean   :104.5   Mean   :2978
#  3rd Qu.:29.00   3rd Qu.:8.000   3rd Qu.:275.8   3rd Qu.:126.0   3rd Qu.:3615
#  Max.   :46.60   Max.   :8.000   Max.   :455.0   Max.   :230.0   Max.   :5140
#
#   acceleration        year           origin                      name
#  Min.   : 8.00   Min.   :70.00   Min.   :1.000   amc matador       :  5
#  1st Qu.:13.78   1st Qu.:73.00   1st Qu.:1.000   ford pinto        :  5
#  Median :15.50   Median :76.00   Median :1.000   toyota corolla    :  5
#  Mean   :15.54   Mean   :75.98   Mean   :1.577   amc gremlin       :  4
# ...

# %%
dim(Auto)
# Out:
# [1] 392   9

# %% [markdown]
# (a) The quantitative variables for Auto are mpg, cylinders, displacement, horsepower, weight, accerlation, and year. Though origin is given by a number, each number refers to a place of origin rather than a quantity. Name is also a qualitative variable.

# %% [markdown]
# (b) and (c) Find the range, standard deviation, and mean of each quantitative predictor

# %%
# mpg
range(mpg)
mean(mpg)
sd(mpg)
# Out:
# [1]  9.0 46.6
# [1] 23.44592
# [1] 7.805007

# %%
# cylinders
range(cylinders)
mean(cylinders)
sd(cylinders) # etc
# Out:
# [1] 3 8
# [1] 5.471939
# [1] 1.705783

# %% [markdown]
# (d) Remove the 10th through 85th observations. Find the range, mean, and standard deviation for the quantitative predictors with the remaining data.

# %%
Auto = Auto[-(10:85),]
attach(Auto)
dim(Auto)
# Out:
# The following objects are masked from Auto (pos = 3):
#
#     acceleration, cylinders, displacement, horsepower, mpg, name,
#     origin, weight, year
#
# The following objects are masked from Auto (pos = 4):
#
#     acceleration, cylinders, displacement, horsepower, mpg, name,
#     origin, weight, year
#
# The following objects are masked from Auto (pos = 5):
#
#     acceleration, cylinders, displacement, horsepower, mpg, name,
#     origin, weight, year
#
# The following objects are masked from Auto (pos = 6):
#
#     acceleration, cylinders, displacement, horsepower, mpg, name,
#     origin, weight, year
# [1] 316   9

# %%
# mpg
range(mpg)
mean(mpg)
sd(mpg)
# Out:
# [1] 11.0 46.6
# [1] 24.40443
# [1] 7.867283

# %%
# cylinders
range(cylinders)
mean(cylinders)
sd(cylinders) # etc
# Out:
# [1] 3 8
# [1] 5.373418
# [1] 1.654179

# %%
length(cylinders)
# Out:
# [1] 316

# %% [markdown]
# (e) Using the full data set, investigate the predictors graphically.

# %%
pairs(Auto)
# Out:
# plot without title

# %%
cylinders = as.factor(cylinders)

# %%
plot(cylinders, mpg)
# Out:
# plot without title

# %%
year = as.factor(year)

# %%
plot(year, mpg)
# Out:
# plot without title

# %%
plot(cylinders, acceleration)
# Out:
# plot without title

# %% [markdown]
# (f) Do your plots suggest that any of the other variables might be useful in predicting mpg? Justify your answer.
#
# Answer: Yes, the plots suggest that we can use the other variables to predict the mpg of a car.
#
# In the above boxplots for mpg with respect to cylinders and year, we can see that mpg has a roughly quadratic relationship with mpg and year has a roughly positive linear relationship with mpg.
#
# In the pairs graph, we can see that displacement, horsepower, and weight all have a negative relationship with mpg. We can also see that acceleration and origin have weak positive relationships with mpg.

# %% [markdown]
# ## Exercise 10
#
# This exercise involves the Boston housing data set in the MASS library.
#
# (a) Load the set and investigate the properties.

# %%
library(MASS)

# %%
Boston
# Out:
#     crim     zn   indus chas nox   rm    age   dis    rad tax ptratio black
# 1   0.00632  18.0 2.31  0    0.538 6.575  65.2 4.0900 1   296 15.3    396.90
# 2   0.02731   0.0 7.07  0    0.469 6.421  78.9 4.9671 2   242 17.8    396.90
# 3   0.02729   0.0 7.07  0    0.469 7.185  61.1 4.9671 2   242 17.8    392.83
# 4   0.03237   0.0 2.18  0    0.458 6.998  45.8 6.0622 3   222 18.7    394.63
# 5   0.06905   0.0 2.18  0    0.458 7.147  54.2 6.0622 3   222 18.7    396.90
# 6   0.02985   0.0 2.18  0    0.458 6.430  58.7 6.0622 3   222 18.7    394.12
# 7   0.08829  12.5 7.87  0    0.524 6.012  66.6 5.5605 5   311 15.2    395.60
# 8   0.14455  12.5 7.87  0    0.524 6.172  96.1 5.9505 5   311 15.2    396.90
# 9   0.21124  12.5 7.87  0    0.524 5.631 100.0 6.0821 5   311 15.2    386.63
# 10  0.17004  12.5 7.87  0    0.524 6.004  85.9 6.5921 5   311 15.2    386.71
# 11  0.22489  12.5 7.87  0    0.524 6.377  94.3 6.3467 5   311 15.2    392.52
# ...

# %%
?Boston

# %%
# The number of rows and columns in the Boston data set can be found on the help page or by executing:
dim(Boston)
# Out:
# [1] 506  14

# %% [markdown]
# The columns of Boston contain predictors involving housing/demographic data for towns near Boston. Each row contains data for a different town.

# %% [markdown]
# (b) Make some pairwise scatterplots of the predictors and describe your findings.

# %%
attach(Boston)

# %%
plot(dis, medv)
# Out:
# plot without title

# %% [markdown]
# Median home value has a weak positive correlation with the distance to employment centers.

# %%
plot(rm, medv)
# Out:
# plot without title

# %% [markdown]
# The median home value has a strong correlation to the average number of rooms per dwelling

# %%
plot(medv, crim)
# Out:
# plot without title

# %% [markdown]
# Crime rate has a week negative relationship with median home value.

# %% [markdown]
# (c) Are any of the predictors associated with the per capita crime rate?
#
# Answer: Yes, see the scatterplot immediately above.

# %% [markdown]
# (d) Do any of the suburbs of Boston appear to have particularly high crime rates?

# %%
hist(crim, breaks=20)
# Out:
# Plot with title “Histogram of crim”

# %%
summary(crim)
range(crim)
sd(crim)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#  0.00632  0.08204  0.25651  3.61352  3.67708 88.97620
# [1]  0.00632 88.97620
# [1] 8.601545

# %%
hist(tax ,breaks=20)
# Out:
# Plot with title “Histogram of tax”

# %%
summary(tax)
sd(tax)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   187.0   279.0   330.0   408.2   666.0   711.0
# [1] 168.5371

# %%
hist(ptratio, breaks=20)
# Out:
# Plot with title “Histogram of ptratio”

# %%
summary(ptratio)
sd(ptratio)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   12.60   17.40   19.05   18.46   20.20   22.00
# [1] 2.164946

# %% [markdown]
# (e) How many suburbs in the data set bound the Charlse river?
#
# Answer: We can make a histogram of the variable chas. The answer is the frequency of the value 1.

# %%
hist(chas)
# Out:
# Plot with title “Histogram of chas”

# %% [markdown]
# (f) What is the median pupil-teacher ration among the towns in the data set?

# %%
median(ptratio)
# Out:
# [1] 19.05

# %% [markdown]
# (g) Find the nieghborhood with the lowest median home value and compare its other predictors with the range of values on the whole data set.

# %%
Boston[order(medv),][1,]
# Out:
#     crim    zn indus chas nox   rm    age dis    rad tax ptratio black lstat
# 399 38.3518 0  18.1  0    0.693 5.453 100 1.4896 24  666 20.2    396.9 30.59
#     medv
# 399 5

# %%
summary(Boston)
# Out:
#       crim                zn             indus            chas
#  Min.   : 0.00632   Min.   :  0.00   Min.   : 0.46   Min.   :0.00000
#  1st Qu.: 0.08204   1st Qu.:  0.00   1st Qu.: 5.19   1st Qu.:0.00000
#  Median : 0.25651   Median :  0.00   Median : 9.69   Median :0.00000
#  Mean   : 3.61352   Mean   : 11.36   Mean   :11.14   Mean   :0.06917
#  3rd Qu.: 3.67708   3rd Qu.: 12.50   3rd Qu.:18.10   3rd Qu.:0.00000
#  Max.   :88.97620   Max.   :100.00   Max.   :27.74   Max.   :1.00000
#       nox               rm             age              dis
#  Min.   :0.3850   Min.   :3.561   Min.   :  2.90   Min.   : 1.130
#  1st Qu.:0.4490   1st Qu.:5.886   1st Qu.: 45.02   1st Qu.: 2.100
#  Median :0.5380   Median :6.208   Median : 77.50   Median : 3.207
#  Mean   :0.5547   Mean   :6.285   Mean   : 68.57   Mean   : 3.795
#  3rd Qu.:0.6240   3rd Qu.:6.623   3rd Qu.: 94.08   3rd Qu.: 5.188
#  Max.   :0.8710   Max.   :8.780   Max.   :100.00   Max.   :12.127
# ...

# %% [markdown]
# (h) Find the number of neighborhood that average more more than 7 rooms per dwelling. More than 8.

# %%
sum(rm>7)
# Out:
# [1] 64

# %%
sum(rm>8)
# Out:
# [1] 13

# %% [markdown]
# We can observe the summary statistics for the neighborhoods which average more than 8 homes per dwelling and compare them to the whole dataset.

# %%
Boston[rm>8,]
# Out:
#     crim    zn indus chas nox    rm    age  dis    rad tax ptratio black  lstat
# 98  0.12083  0  2.89 0    0.4450 8.069 76.0 3.4952  2  276 18.0    396.90 4.21
# 164 1.51902  0 19.58 1    0.6050 8.375 93.9 2.1620  5  403 14.7    388.45 3.32
# 205 0.02009 95  2.68 0    0.4161 8.034 31.9 5.1180  4  224 14.7    390.55 2.88
# 225 0.31533  0  6.20 0    0.5040 8.266 78.3 2.8944  8  307 17.4    385.05 4.14
# 226 0.52693  0  6.20 0    0.5040 8.725 83.0 2.8944  8  307 17.4    382.00 4.63
# 227 0.38214  0  6.20 0    0.5040 8.040 86.5 3.2157  8  307 17.4    387.38 3.13
# 233 0.57529  0  6.20 0    0.5070 8.337 73.3 3.8384  8  307 17.4    385.91 2.47
# 234 0.33147  0  6.20 0    0.5070 8.247 70.4 3.6519  8  307 17.4    378.95 3.95
# 254 0.36894 22  5.86 0    0.4310 8.259  8.4 8.9067  7  330 19.1    396.90 3.54
# 258 0.61154 20  3.97 0    0.6470 8.704 86.9 1.8010  5  264 13.0    389.70 5.12
# 263 0.52014 20  3.97 0    0.6470 8.398 91.5 2.2885  5  264 13.0    386.86 5.91
# ...

# %%
summary(Boston[rm>8,])
# Out:
#       crim               zn            indus             chas
#  Min.   :0.02009   Min.   : 0.00   Min.   : 2.680   Min.   :0.0000
#  1st Qu.:0.33147   1st Qu.: 0.00   1st Qu.: 3.970   1st Qu.:0.0000
#  Median :0.52014   Median : 0.00   Median : 6.200   Median :0.0000
#  Mean   :0.71879   Mean   :13.62   Mean   : 7.078   Mean   :0.1538
#  3rd Qu.:0.57834   3rd Qu.:20.00   3rd Qu.: 6.200   3rd Qu.:0.0000
#  Max.   :3.47428   Max.   :95.00   Max.   :19.580   Max.   :1.0000
#       nox               rm             age             dis
#  Min.   :0.4161   Min.   :8.034   Min.   : 8.40   Min.   :1.801
#  1st Qu.:0.5040   1st Qu.:8.247   1st Qu.:70.40   1st Qu.:2.288
#  Median :0.5070   Median :8.297   Median :78.30   Median :2.894
#  Mean   :0.5392   Mean   :8.349   Mean   :71.54   Mean   :3.430
#  3rd Qu.:0.6050   3rd Qu.:8.398   3rd Qu.:86.50   3rd Qu.:3.652
#  Max.   :0.7180   Max.   :8.780   Max.   :93.90   Max.   :8.907
#       rad              tax           ptratio          black
# ...

# %%
summary(Boston)
# Out:
#       crim                zn             indus            chas
#  Min.   : 0.00632   Min.   :  0.00   Min.   : 0.46   Min.   :0.00000
#  1st Qu.: 0.08204   1st Qu.:  0.00   1st Qu.: 5.19   1st Qu.:0.00000
#  Median : 0.25651   Median :  0.00   Median : 9.69   Median :0.00000
#  Mean   : 3.61352   Mean   : 11.36   Mean   :11.14   Mean   :0.06917
#  3rd Qu.: 3.67708   3rd Qu.: 12.50   3rd Qu.:18.10   3rd Qu.:0.00000
#  Max.   :88.97620   Max.   :100.00   Max.   :27.74   Max.   :1.00000
#       nox               rm             age              dis
#  Min.   :0.3850   Min.   :3.561   Min.   :  2.90   Min.   : 1.130
#  1st Qu.:0.4490   1st Qu.:5.886   1st Qu.: 45.02   1st Qu.: 2.100
#  Median :0.5380   Median :6.208   Median : 77.50   Median : 3.207
#  Mean   :0.5547   Mean   :6.285   Mean   : 68.57   Mean   : 3.795
#  3rd Qu.:0.6240   3rd Qu.:6.623   3rd Qu.: 94.08   3rd Qu.: 5.188
#  Max.   :0.8710   Max.   :8.780   Max.   :100.00   Max.   :12.127
# ...
